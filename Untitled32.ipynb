# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
df.head()
# Out:
#                'ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0  APPC90493171225  Female  23/07/79           15/07/16    C10001
# 1  APPD40611263344    Male  07/12/86           04/07/16    C10003
# 2  APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3  APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4  APPG60994436641    Male  19/04/85           20/07/16    C10002
#
#   City_Category Employer_Code Employer_Category1  Employer_Category2  \
# 0             A    COM0044082                  A                 4.0
# 1             A    COM0000002                  C                 1.0
# 2             C    COM0005267                  C                 4.0
# 3             C    COM0004143                  A                 4.0
# 4             A    COM0001781                  A                 4.0
#
#    Monthly_Income    ...    Contacted Source Source_Category Existing_EMI  \
# 0          2000.0    ...            N   S122               G          0.0
# ...

# %%
df_test.head()
# Out:
#                'ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0  APPA70109647212    Male  03/06/88           05/07/16    C10028
# 1  APPB10687939341    Male  13/07/81           01/07/16    C10003
# 2  APPC80449411414  Female  19/11/90           01/07/16    C10009
# 3  APPD30665094501  Female  15/10/92           01/07/16    C10005
# 4  APPE80379821637    Male  21/09/88           01/07/16    C10005
#
#   City_Category Employer_Code Employer_Category1  Employer_Category2  \
# 0             C    COM0002222                  A                 4.0
# 1             A    COM0001784                  C                 4.0
# 2             B    COM0045260                  B                 4.0
# 3             A    COM0000085                  A                 3.0
# 4             A    COM0006422                  A                 4.0
#
#    Monthly_Income  ...  Primary_Bank_Type Contacted Source Source_Category  \
# ...

# %%
df['source']='train';
df_test['source']='test'

# %%
data=pd.concat([df,df_test],ignore_index=True)

# %%
data.head()
# Out:
#                'ID  Approved City_Category City_Code Contacted  \
# 0  APPC90493171225       0.0             A    C10001         N
# 1  APPD40611263344       0.0             A    C10003         Y
# 2  APPE70289249423       0.0             C    C10125         Y
# 3  APPF80273865537       0.0             C    C10477         Y
# 4  APPG60994436641       0.0             A    C10002         Y
#
#   Customer_Existing_Primary_Bank_Code       DOB    EMI Employer_Category1  \
# 0                                B001  23/07/79    NaN                  A
# 1                                B002  07/12/86  953.0                  C
# 2                                B003  10/12/82    NaN                  C
# 3                                B003  30/01/89    NaN                  A
# 4                                B001  19/04/85    NaN                  A
#
#    Employer_Category2  ...   Interest_Rate  Lead_Creation_Date Loan_Amount  \
# ...

# %%
print(df.shape,df_test.shape,data.shape)
# Out:
# (69713, 23) (30037, 22) (99750, 23)

# %%
data.isnull().sum()
# Out:
# 'ID                                        0
# Approved                               30037
# City_Category                           1128
# City_Code                               1128
# Contacted                                  0
# Customer_Existing_Primary_Bank_Code    13428
# DOB                                       18
# EMI                                    67822
# Employer_Category1                      5623
# Employer_Category2                      5993
# Employer_Code                           5623
# Existing_EMI                              83
# Gender                                     0
# Interest_Rate                          67822
# Lead_Creation_Date                         0
# Loan_Amount                            39580
# Loan_Period                            39580
# Monthly_Income                             0
# Primary_Bank_Type                      13428
# Source                                     0
# Source_Category                            0
# ...

# %%
df.isnull().sum()
# Out:
# 'ID                                        0
# Gender                                     0
# DOB                                       15
# Lead_Creation_Date                         0
# City_Code                                814
# City_Category                            814
# Employer_Code                           4018
# Employer_Category1                      4018
# Employer_Category2                      4298
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code     9391
# Primary_Bank_Type                       9391
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                              51
# Loan_Amount                            27709
# Loan_Period                            27709
# Interest_Rate                          47437
# EMI                                    47437
# Var1                                       0
# ...

# %%
data.describe()
# Out:
#            Approved           EMI  Employer_Category2   Existing_EMI  \
# count  69713.000000  31928.000000        93757.000000   99667.000000
# mean       0.014631   1099.485718            3.722623     357.310193
# std        0.120073    745.125218            0.803623    1990.517471
# min        0.000000    118.000000            1.000000       0.000000
# 25%        0.000000    642.750000            4.000000       0.000000
# 50%        0.000000    943.000000            4.000000       0.000000
# 75%        0.000000   1293.000000            4.000000     350.000000
# max        1.000000  13556.000000            4.000000  545436.500000
#
#        Interest_Rate    Loan_Amount   Loan_Period  Monthly_Income  \
# count   31928.000000   60170.000000  60170.000000    9.975000e+04
# mean       19.233814   39445.986372      3.894399    5.126893e+03
# std         5.857761   30667.188339      1.162487    1.466628e+05
# min        11.990000    5000.000000      1.000000    0.000000e+00
# ...

# %%
array(df['Monthly_Income'])
# Out:
# array([ 2000.,  3500.,  2250., ...,  1600.,  9893.,  4230.])

# %%
df['Monthly_Income']=df['Monthly_Income'].astype(float)

# %%
df.dtypes
# Out:
# 'ID                                     object
# Gender                                  object
# DOB                                     object
# Lead_Creation_Date                      object
# City_Code                               object
# City_Category                           object
# Employer_Code                           object
# Employer_Category1                      object
# Employer_Category2                     float64
# Monthly_Income                         float64
# Customer_Existing_Primary_Bank_Code     object
# Primary_Bank_Type                       object
# Contacted                               object
# Source                                  object
# Source_Category                         object
# Existing_EMI                           float64
# Loan_Amount                            float64
# Loan_Period                            float64
# Interest_Rate                          float64
# EMI                                    float64
# ...

# %%
df.describe()
# Out:
#        Employer_Category2  Monthly_Income   Existing_EMI    Loan_Amount  \
# count        65415.000000    6.971300e+04   69662.000000   42004.000000
# mean             3.720187    5.622250e+03     360.928751   39429.982859
# std              0.807374    1.747671e+05    2288.517927   30727.595990
# min              1.000000    0.000000e+00       0.000000    5000.000000
# 25%              4.000000    1.650000e+03       0.000000   20000.000000
# 50%              4.000000    2.500000e+03       0.000000   30000.000000
# 75%              4.000000    4.000000e+03     350.000000   50000.000000
# max              4.000000    3.838384e+07  545436.500000  300000.000000
#
#         Loan_Period  Interest_Rate           EMI          Var1      Approved
# count  42004.000000   22276.000000  22276.000000  69713.000000  69713.000000
# mean       3.890629      19.213570   1101.466242      3.948446      0.014631
# std        1.167491       5.847136    752.661394      3.819214      0.120073
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['Contacted'], bins=5)
# Out:
# (array([ 34978.,      0.,      0.,      0.,  64772.]),
#  array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <a list of 5 Patch objects>)

# %%
gender_dependant=pd.crosstab(data['Gender'],data['Approved'])

# %%
gender_dependant
# Out:
# Approved    0.0  1.0
# Gender
# Female    29516  248
# Male      39177  772

# %%
gender_dependant.plot(kind='bar')

# %%
City_Category=pd.crosstab(data['City_Category'],data['Approved'],values=data['Monthly_Income'],aggfunc='sum')

# %%
City_Category
#sum of monthly income on the basis of city category
# Out:
# Approved                0.0        1.0
# City_Category
# A              3.098584e+08  5531424.1
# B              2.410123e+07   453266.3
# C              4.843494e+07   433292.1

# %%
City_Category.plot(y=df['Approved'],kind='bar',figsize=[10,5])

# %%
#Divide into test and train:
train = data.loc[data['source']=="train"]
test = data.loc[data['source']=="test"]
